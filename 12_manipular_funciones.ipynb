# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Desplazamientos verticales y horizontales
#
# Siendo $c$ una constante mayor que cero, entonces la gráfica:
#
# - $y=f(x)+c$ se desplaza $c$ unidades hacia arriba.
# - $y=f(x)-c$ se desplaza $c$ unidades hacia abajo.
# - $y=f(x-c)$ se desplaza $c$ unidades hacia la derecha.
# - $y=f(x+c)$ se desplaza $c$ unidades hacia la izquierda.

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion
def f(x):
    return (x**2)

# Definimos el valor de C
c = 0

# Definimos el valor de X
x = np.linspace(-5,5, num=N)

# Definimos Y
y = f(x)

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# La interseccion de la parabola esta en 0,0
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return (x**2)

# Definimos el valor de C
c = 5

# Definimos el valor de X
x = np.linspace(-5,5, num=N)

# Definimos Y Agregamos '+ c' afuera de la funcion Para que la parabola suba
y = f(x) + c

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# La interseccion de la parabola esta en 0,5 La parabola subio 5 puntos
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return (x**2)

# Definimos el valor de C
c = 5

# Definimos el valor de X
x = np.linspace(-5,5, num=N)

# Definimos Y Agregamos '- c' afuera de la funcion para que la parabola baje
y = f(x) - c

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# La interseccion de la parabola esta en 0,-5 La parabola bajo 5 puntos
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return (x**2)

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-5,5, num=N)

# Definimos Y Agregamos '- c' adentro de la funcion para que la parabola se mueva a la derecha
y = f(x - c) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# La interseccion de la parabola esta en 2,0 La parabola bajo 5 puntos
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return (x**2)

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-5,5, num=N)

# Definimos Y Agregamos '+ c' adentro de la funcion para que la parabola se mueva a la izquierda
y = f(x + c) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# La interseccion de la parabola esta en 2,0 La parabola bajo 5 puntos
plt.show()

# %% [markdown]
# ## Alargamientos y compresiones
#
# Siendo $c$ una constante mayor que cero, entonces la gráfica:
#
# - $y=c \cdot f(x)$ alarga la gráfica verticalmente en un factor de $c$.
# - $y= \frac{1}{c} \cdot f(x)$ comprime la gráfica verticalmente en un factor de $c$.
# - $y=f(c \cdot x)$ comprime la gráfica horizontelmente en un factor de $c$.
# - $y= f(\frac{1}{c} \cdot x )$ alarga la gráfica horizontelmente en un factor de $c$.

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return np.sin(x)

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y 
y = f(x) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
ax.set_ylim(-3,3)

# Funcion sin parametros extra
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return np.sin(x)

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y lo multiplicamos por C para alargar la grafica verticalmente
y = c*f(x) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
ax.set_ylim(-3,3)

# Funcion expandida verticalmente
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return np.sin(x)

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y lo multiplicamos por (1/C) para comprimir la grafica verticalmente
y = (1/c)*f(x) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
ax.set_ylim(-3,3)

# Funcion comprimida verticalmente
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return np.sin(x)

# Definimos el valor de C
c = 10

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y lo multiplicamos por C dentro de la funcion para comprimir la grafica horizontalmente
y = f(x * c) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
ax.set_ylim(-3,3)

# Funcion comprimida horizontalmente
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return np.sin(x)

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y lo multiplicamos por (1/C) dentro de la funcion para expandir la grafica horizontalmente
y = f(x * (1/c)) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
ax.set_ylim(-3,3)

# Funcion expandida horizontalmente
plt.show()

# %% [markdown]
# ## Reflexiones
#
# - $y=-f(x)$ refleja la gráfica respecto al eje x.
# - $y=f(-x)$ refleja la gráfica respecto al eje y.

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return x**3

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y
y = f(x) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# Funcion original
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return x**3

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y donde f es negativo para reflejar en el eje X
y = -f(x) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# Funcion original
plt.show()

# %%
# Definimos la cantidad de puntos para la grafica
N = 1000

# Definimos la funcion.
def f(x):
    return x**3

# Definimos el valor de C
c = 2

# Definimos el valor de X
x = np.linspace(-15,15, num=N)

# Definimos Y donde x es negativo para reflejar en el eje Y
y = f(-x) 

# Definimos el plot y dos lineas
fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# Funcion original
plt.show()

# %% [markdown]
# Ejercicio

# %%
#-y=-f(x) refleja la gráfica respecto al eje x.

N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)
y = f(x);
y1 = -f(x); 

fig, ax = plt.subplots()
ax.plot(x,y,label="f(x)", color='g', linestyle='-')
ax.plot(x,y1, label="-f(x)", color='b', linestyle='--')
ax.legend(loc=9)
plt.title('Refleja la gráfica respecto al eje x')
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r');
y=f(-x) #refleja la gráfica respecto al eje y. Los datos que tengo a la izquierda pasan a la derecha y los que están a la derecha pasan a la izquierda.
N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)
y = f(x);
y1 = f(-x); 

fig, ax = plt.subplots()
ax.plot(x,y,label="f(x)", color='g', linestyle='-')
ax.plot(x,y1, label="f(-x)", color='b', linestyle='--')
ax.legend(loc=9)
plt.title('Refleja la gráfica respecto al eje y')
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r');
